# %%
from model import SearchCifarNet

model = SearchCifarNet()
model.init_model(model_init='he_fout', init_div_groups=False)
model.cuda()
# Out:
# SearchCifarNet(
#   (first_conv): ConvLayer(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (act): ReLU6(inplace=True)
#     (sequence): Sequential(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU6(inplace=True)
#     )
#   )
#   (blocks): ModuleList(
#     (0): MBInvertedConvLayer(
#       (inverted_bottleneck): Sequential()
#       (depth_conv): Sequential(
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU6(inplace=True)
#       )
#       (point_linear): Sequential(
# ...

# %%
from torchinfo import summary

summary(model, (1, 3, 32, 32), device='cuda')
# Out:
# ...
# Layer (type:depth-idx)                             Output Shape              Param #
# ...
# SearchCifarNet                                     --                        --
# ├─ConvLayer: 1-1                                   --                        (recursive)
# │    └─Conv2d: 2-1                                 --                        (recursive)
# │    └─BatchNorm2d: 2-2                            --                        (recursive)
# │    └─ReLU6: 2-3                                  --                        --
# │    └─Sequential: 2-4                             --                        (recursive)
# │    │    └─Conv2d: 3-1                            --                        (recursive)
# │    │    └─BatchNorm2d: 3-2                       --                        (recursive)
# │    │    └─ReLU6: 3-3                             --                        --
# ├─ModuleList: 1-2                                  --                        --
# ...

# %%
import torch
model(torch.zeros(1, 3, 224, 224))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/jungin500/Workspace/nni-workspace/nni/study/05-3x3_5x5_7x7net-cifar100/searchcifarnet-inspection.ipynb Cell 3' in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bipcvl-desktop/home/jungin500/Workspace/nni-workspace/nni/study/05-3x3_5x5_7x7net-cifar100/searchcifarnet-inspection.ipynb#ch0000002vscode-remote?line=0'>1</a> import torch
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bipcvl-desktop/home/jungin500/Workspace/nni-workspace/nni/study/05-3x3_5x5_7x7net-cifar100/searchcifarnet-inspection.ipynb#ch0000002vscode-remote?line=1'>2</a> model(torch.zeros(1, 3, 224, 224))
#
# File ~/anaconda3/envs/nni/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
# ...
